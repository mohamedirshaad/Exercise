# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("cleaning_ex3.csv")

# %%
data.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
data.tail()
# Out:
#           Job Title Salary Estimate  \
# 655  Data Scientist        105-167
# 656  Data Scientist        105-167
# 657  Data Scientist        105-167
# 658  Data Scientist        105-167
# 659  Data Scientist        105-167
#
#                                        Job Description  Rating  \
# 655  Summary\n\nWe’re looking for a data scientist ...     3.6
# 656  Job Description\nBecome a thought leader withi...     0.0
# 657  Join a thriving company that is changing the w...     0.0
# 658  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 659  Description\n\nThe Data Scientist will be part...     2.7
#
#              Company Name           Location       Headquarters  \
# 655              TRANZACT       Fort Lee, NJ       Fort Lee, NJ
# 656                  JKGT  San Francisco, CA  San Francisco, CA
# 657            AccessHope      Irwindale, CA      Irwindale, CA
# 658  ChaTeck Incorporated  San Francisco, CA    Santa Clara, CA
# ...

# %%
data["Size"].unique()
# Out:
# array(['1001 to 5000 employees', '5001 to 10000 employees',
#        '501 to 1000 employees', '51 to 200 employees',
#        '10000 to 10000+ employees', '201 to 500 employees',
#        '1 to 50 employees', '0 to 0 employees'], dtype=object)

# %%
data.loc[data["Size"]== "-1","Size"] ="0 to 0 employees"

# %%
data.loc[data["Size"]== "Unknown","Size"] ="0 to 0 employees"

# %%
data.loc[data["Size"]== "10000+ employees","Size"] ="10000 to 10000+ employees"

# %%
data["minimum_employees"]=data["Size"].str.split(" ").str[0]

# %%
data["maximum_employees"]=data["Size"].str.split(" ").str[2]

# %%
data["Revenue"].unique()
# Out:
# array(['$1 million', '$1 to $2 billion (USD)',
#        '$100 to $500 million (USD)', '$10+ billion (USD)',
#        '$2 to $5 billion (USD)', '$500 million to $1 billion (USD)',
#        '$5 to $10 billion (USD)', '$10 to $25 million (USD)',
#        '$25 to $50 million (USD)', '$50 to $100 million (USD)',
#        '$1 to $5 million (USD)', '$5 to $10 million (USD)',
#        'Less than $1 million (USD)'], dtype=object)

# %%
data.loc[data["Revenue"]=="Unknown / Non-Applicable","Revenue"]="$1 million"

# %%
data.loc[data["Revenue"]=="-1","Revenue"]="$1 million"

# %%
# the_revenue_list = ['Unknown / Non-Applicable', '-1']

# for x in the_revenue_list:
#     data.loc[data["Revenue"]==x,"Revenue"]="$1 million"

# %%
data["Salary Estimate"].unique()
# Out:
# array(['137-171 ', '75-131 ', '79-131 ', '99-132 ', '90-109 ', '101-165 ',
#        '56-97 ', '79-106 ', '71-123 ', '90-124 ', '91-150 ', '141-225 ',
#        '145-225', '79-147 ', '122-146 ', '112-116 ', '110-163 ',
#        '124-198 ', '79-133 ', '69-116 ', '31-56 ', '95-119 ', '212-331 ',
#        '66-112 ', '128-201 ', '138-158 ', '80-132 ', '87-141 ', '92-155 ',
#        '105-167 '], dtype=object)

# %%
data["minium_salary"]=data["Salary Estimate"].str.split("-").str[0]

# %%
data["maximum_salary"]=data["Salary Estimate"].str.split("-").str[1]

# %%
data["minium_salary"]=data["minium_salary"].astype(int)

# %%
data["maximum_salary"]=data["maximum_salary"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          660 non-null    object
#  1   Salary Estimate    660 non-null    object
#  2   Job Description    660 non-null    object
#  3   Rating             660 non-null    float64
#  4   Company Name       660 non-null    object
#  5   Location           660 non-null    object
#  6   Headquarters       660 non-null    object
#  7   Size               660 non-null    object
#  8   Type of ownership  660 non-null    object
#  9   Industry           660 non-null    object
#  10  Sector             660 non-null    object
#  11  Revenue            660 non-null    object
#  12  company_age        660 non-null    int64
#  13  seniority          660 non-null    object
#  14  minimum_employees  660 non-null    object
#  15  maximum_employees  660 non-null    object
# ...

# %%
data["average_salary"]=(data["maximum_salary"]+data["minium_salary"])/2

# %%
data["Province"]=data["Location"].str.split(",").str[1]
data["State"]=data["Location"].str.split(",").str[0]

# %%
data.loc[data["Headquarters"]== "-1","Headquarters"] = data["Location"]

# %%
data["Province_HQ"]=data["Headquarters"].str.split(",").str[1]
data["State_HQ"]=data["Headquarters"].str.split(",").str[0]
